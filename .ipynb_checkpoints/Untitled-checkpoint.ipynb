# %%
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# ...

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\ibrahim/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-12-24 Python-3.9.13 torch-1.8.1+cu111 CUDA:0 (GeForce RTX 2070, 8192MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
img = 'https://i4.hurimg.com/i/hurriyet/75/750x422/620008c04e3fe118b805b64c.jpg'

# %%
import io

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 422x750 20 cars, 2 buss, 2 trucks
# Speed: 251.3ms pre-process, 27.0ms inference, 7.0ms NMS per image at shape (1, 3, 384, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.render()
# Out:
# [array([[[209, 216, 242],
#          [199, 206, 232],
#          [203, 210, 236],
#          ...,
#          [130, 133, 112],
#          [133, 139, 113],
#          [153, 159, 131]],
#
#         [[209, 216, 242],
#          [199, 206, 232],
#          [202, 209, 235],
#          ...,
#          [ 88,  91,  70],
#          [ 98, 104,  78],
#          [100, 106,  78]],
#
#         [[209, 216, 242],
#          [199, 206, 232],
#          [202, 209, 235],
#          ...,
#          [139, 143, 120],
#          [140, 144, 119],
#          [120, 127,  96]],
#
#         ...,
#
#         [[183, 168, 175],
#          [162, 147, 154],
#          [178, 163, 170],
#          ...,
#          [104,  93,  99],
#          [108,  97, 103],
#          [115, 104, 110]],
#
#         [[183, 168, 175],
#          [162, 147, 154],
#          [178, 163, 170],
#          ...,
#          [105,  94, 100],
#          [108,  97, 103],
#          [115, 104, 110]],
#
#         [[183, 168, 175],
# ...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    #cv2_imshow('YOLO', np.squeeze(results.render()))
    cv2.imshow("Test", np.squeeze(results.render()))
  
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid   # Unique identifier
import os
import time

# %%
IMAGES_PATH = os.path.join('data', 'images') #/data/images
labels = ['banana', 'tomatoes']
print(IMAGES_PATH)
number_imgs = 20
# Out:
# data\images

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        cv2.imshow("Test", frame)
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# data\images\banana.14c0e6e7-83bb-11ed-ad00-d2a76a043785.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# data\images\banana.14c37a4f-83bb-11ed-ba87-d2a76a043785.jpg
# ...
# data\images\banana.14c37a50-83bb-11ed-9b32-d2a76a043785.jpg
# ...
# data\images\banana.14c37a51-83bb-11ed-9d53-d2a76a043785.jpg
# ...
# data\images\banana.14c37a52-83bb-11ed-8009-d2a76a043785.jpg
# ...
# data\images\banana.14c37a53-83bb-11ed-b04c-d2a76a043785.jpg
# ...
# data\images\banana.14c37a54-83bb-11ed-aff9-d2a76a043785.jpg
# ...
# data\images\banana.14c37a55-83bb-11ed-b96e-d2a76a043785.jpg
# ...
# data\images\banana.14c37a56-83bb-11ed-b2e4-d2a76a043785.jpg
# ...
# data\images\banana.14c37a57-83bb-11ed-80bc-d2a76a043785.jpg
# ...
# data\images\banana.14c37a58-83bb-11ed-ba9a-d2a76a043785.jpg
# ...
# data\images\banana.14c37a59-83bb-11ed-8206-d2a76a043785.jpg
# ...
# data\images\banana.14c37a5a-83bb-11ed-a7ae-d2a76a043785.jpg
# ...
# data\images\banana.14c37a5b-83bb-11ed-916c-d2a76a043785.jpg
# ...
# data\images\banana.14c37a5c-83bb-11ed-907d-d2a76a043785.jpg
# ...
# data\images\banana.14c37a5d-83bb-11ed-9710-d2a76a043785.jpg
# ...
# data\images\banana.14c37a5e-83bb-11ed-8a90-d2a76a043785.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 320 --batch 16  --epochs 100 --data dataset.yml --weights yolov5s.pt --workers 1 --batch-size = 2 --num_workers = 1
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ibrahim\Documents\Yolo\Yolo\yolov5\train.py", line 29, in <module>
#     import torch
#   File "C:\Users\ibrahim\anaconda3\lib\site-packages\torch\__init__.py", line 123, in <module>
#     raise err
# OSError: [WinError 1455] Bu işlemin tamamlanması için disk belleği dosyası çok küçük. Error loading "C:\Users\ibrahim\anaconda3\lib\site-packages\torch\lib\caffe2_detectron_ops_gpu.dll" or one of its dependencies.

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp15/weights/last.pt', force_reload=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18180\1601075308.py in <module>
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp15/weights/last.pt', force_reload=True)
#
# NameError: name 'torch' is not defined

# %%
img = os.path.join('data', 'images', 'banana.8bf83b2a-7fcb-11ed-9514-744ca1466e18.jpg')

# %%
results = model(img)

# %%
results.print()

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
